# %%
# !git clone https://github.com/SeanNaren/warp-ctc.git
# !cd warp-ctc; mkdir build; cd build; cmake ..; make
# !export CUDA_HOME="/usr/local/cuda"
# !cd warp-ctc/pytorch_binding && python setup.py install
# !git clone --recursive https://github.com/NVIDIA/apex.git
# !cd apex && pip install .
# Out:
# Streaming output truncated to the last 5000 lines.
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/ATen/core/dispatch/Dispatcher.h:3,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/ATen/core/TensorMethods.h:10,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Tensor.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Context.h:4,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/ATen/ATen.h:5,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
# ...

# %%
# !git clone --recursive https://github.com/parlance/ctcdecode.git
# !cd ctcdecode && pip install .

# %%
# !git clone --recursive https://github.com/SeanNaren/deepspeech.pytorch.git
# !cd deepspeech.pytorch && pip install -r requirements.txt
# %cd deepspeech.pytorch
# !wget https://github.com/SeanNaren/deepspeech.pytorch/releases/download/v2.0/librispeech_pretrained_v2.pth
# Out:
# Cloning into 'deepspeech.pytorch'...
# remote: Enumerating objects: 1421, done.
# remote: Total 1421 (delta 0), reused 0 (delta 0), pack-reused 1421
# Receiving objects: 100% (1421/1421), 546.68 KiB | 10.31 MiB/s, done.
# Resolving deltas: 100% (887/887), done.
# ...
#      |████████████████████████████████| 51kB 1.7MB/s
# ...
#      |████████████████████████████████| 686kB 6.9MB/s
# ...
#      |████████████████████████████████| 204kB 20.0MB/s
# ...
#   Created wheel for python-levenshtein: filename=python_Levenshtein-0.12.0-cp36-cp36m-linux_x86_64.whl size=144785 sha256=853a4a8ff27c60a28a2f67974bb67d3e5cf38c045e4fc8d934ba025c7ca8348c
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655250 sha256=532802a631a4b1b8681df1290845df9ae64bcf6832c3c217406aab1312f66be6
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...

# %%
# !apt -qq install -y sox
# Out:
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 25 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,715 kB of additional disk space will be used.
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 144568 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# ...

# %%
# !python data/librispeech.py --files-to-use='dev-clean.tar.gz'
# Out:
# Skipping url: http://www.openslr.org/resources/12/train-clean-100.tar.gz
# Skipping url: http://www.openslr.org/resources/12/train-clean-360.tar.gz
# Skipping url: http://www.openslr.org/resources/12/train-other-500.tar.gz
# Sorting manifests...
# Pruning manifests between 1 and 15 seconds
# 0it [00:00, ?it/s]
#
#
# Unpacking dev-clean.tar.gz...
# Converting flac files to wav and extracting transcripts...
# 139it [00:31,  4.44it/s]
# Finished http://www.openslr.org/resources/12/dev-clean.tar.gz
# Skipping url: http://www.openslr.org/resources/12/dev-other.tar.gz
# Sorting manifests...
# 100% 2703/2703 [00:00<00:00, 79957.71it/s]
#
#
# Skipping url: http://www.openslr.org/resources/12/test-clean.tar.gz
# Sorting manifests...
# 0it [00:00, ?it/s]
#
#
# Skipping url: http://www.openslr.org/resources/12/test-other.tar.gz
# Sorting manifests...
# 0it [00:00, ?it/s]

# %%
# !zip -r compressed.zip ./LibriSpeech_dataset/val/

# %%
#comment out matplotlib.use('TkAgg') in /content/deepspeech.pytorch/data/spec_augment.py

# %%
# !python test.py --model-path librispeech_pretrained_v2.pth --test-manifest libri_val_manifest.csv --batch-size=1 --num-workers=1
# Out:
#   0% 0/2703 [00:00<?, ?it/s]False
# None
# 16000
# 0.02
# 0.01
# <function hamming at 0x7ff03372b0d0>
# True
# False
# False
# None
# 16000
# 0.02
# 0.01
# <function hamming at 0x7ff03372b0d0>
# True
# False
# Traceback (most recent call last):
#   File "test.py", line 94, in <module>
#     half=args.half)
#   File "test.py", line 27, in evaluate
#     for i, (data) in tqdm(enumerate(test_loader), total=len(test_loader)):
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1091, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 345, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 856, in _next_data
#     return self._process_data(data)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 881, in _process_data
#     data.reraise()
# ...

# %%
# !python test.py --model-path librispeech_pretrained_v2.pth --test-manifest test_adversarial.csv --cuda
# Out:
#   0% 0/1 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# [['LIDEL  TNOEVRE NOD ONE']]
# [['I DONT KNOW YOU FROM ADAM']]
# 100% 1/1 [00:00<00:00,  5.87it/s]
# Test Summary 	Average WER 100.000	Average CER 75.000

# %%
# !python test.py --model-path librispeech_pretrained_v2.pth --test-manifest test_adversarial_medium.csv --cuda
# Out:
#   0% 0/1 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# [["I DON'T KNOW YOU CLOMADEM"]]
# [['I DONT KNOW YOU FROM ADAM']]
# 100% 1/1 [00:00<00:00,  6.27it/s]
# Test Summary 	Average WER 50.000	Average CER 20.000

# %%
# !python test.py --model-path librispeech_pretrained_v2.pth --test-manifest original-long.csv --cuda
# Out:
#   0% 0/1 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# [['WHY DO YOU WANT TO FIND THAT SORT OF PERSONIN THE ARAB ASK']]
# [['WHY DO YOU WANT TO FIND THAT SORT OF PERSON THE ARAB ASKED']]
# 100% 1/1 [00:00<00:00,  3.27it/s]
# Test Summary 	Average WER 15.385	Average CER 8.696

# %%
# !python test.py --model-path librispeech_pretrained_v2.pth --test-manifest adversarial_long2long.csv --cuda
# Out:
#   0% 0/1 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# [['WHY DO YOU WANT TO FIND THAT SORT OF FERSEO WITHTE ARROW PAS']]
# [['WHY DO YOU WANT TO FIND THAT SORT OF PERSON THE ARAB ASKED']]
# 100% 1/1 [00:00<00:00,  3.25it/s]
# Test Summary 	Average WER 30.769	Average CER 26.087

# %%
# !python test.py --model-path librispeech_pretrained_v2.pth --test-manifest adversarial_long2short.csv --cuda
# Out:
#   0% 0/1 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# [['WHY DO YOU WANT TO FIND THAT SORT OF PERSONIN THE ARROB ASKE']]
# [['WHY DO YOU WANT TO FIND THAT SORT OF PERSON THE ARAB ASKED']]
# 100% 1/1 [00:00<00:00,  3.15it/s]
# Test Summary 	Average WER 23.077	Average CER 10.870

# %%
# %cd deepspeech.pytorch
# !python test.py --model-path librispeech_pretrained_v2.pth --test-manifest libri_test_clean_manifest.csv --cuda --half
# Out:
# /content/deepspeech.pytorch
#   0% 0/131 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# 100% 131/131 [01:38<00:00,  1.33it/s]
# Test Summary 	Average WER 9.917	Average CER 3.307
